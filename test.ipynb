# %%
# !nvidia-smi
# Out:
# Thu Jun  3 18:24:36 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 440.64       Driver Version: 440.64       CUDA Version: 10.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:07.0 Off |                    0 |
# | N/A   55C    P0    19W /  70W |      0MiB / 15109MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# ...

# %%
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2019 NVIDIA Corporation
# Built on Wed_Apr_24_19:10:27_PDT_2019
# Cuda compilation tools, release 10.1, V10.1.168

# %%
# !nsys --version
# Out:
# /usr/bin/sh: nsys: command not found

# %%
# !ls /cvmfs/sft-nightlies.cern.ch/lcg/views/dev4cuda/Thu/x86_64-centos7-gcc8-opt/bin/
# Out:
# 2to3				   mvnDebug
# 2to3-3.7			   mvnDebug.cmd
# 7z				   mvnyjp
# 7za				   myisamchk
# 7zCon.sfx			   myisam_ftdump
# 7z.so				   myisamlog
# aclocal				   myisampack
# aclocal-1.16			   my_print_defaults
# acyclic				   myrocks_hotbackup
# addRandomAccess			   mysql
# aggregate_profile.pl		   mysqlaccess
# agile-config			   mysqladmin
# agile-runmc			   mysqlbinlog
# aida2flat			   mysqlcheck
# aida2yoda			   mysql_client_test
# ampt2u				   mysql_config
# anajob				   mysql_convert_table_format
# animate				   mysqld
# ant				   mysqld_multi
# ant.bat				   mysqld_safe
# ant.cmd				   mysqld_safe_helper
# antenv.cmd			   mysqldump
# antRun				   mysqldumpslow
# antRun.bat			   mysql_find_rows
# antRun.pl			   mysql_fix_extensions
# apfel				   mysqlhotcopy
# apfel-config			   mysqlimport
# appletviewer			   mysql_ldb
# applygeo			   mysql_plugin
# archspec			   mysql_secure_installation
# aria_chk			   mysql_setpermission
# aria_dump_log			   mysqlshow
# ...

# %%
# !nvprof ls
# Out:
# Untitled.ipynb
# ======== Warning: No profile data collected.

# %%
# !nvcc -arch=sm_70 -o test-gpu 01-test/01-test.cu -run
# Out:
# Hello from the CPU.
# Hello from the GPU.

# %%
# !nvprof ./test-gpu
# Out:
# Hello from the CPU.
# ==625== NVPROF is profiling process 625, command: ./test-gpu
# ======== Profiling result:
# No kernels were profiled.
#             Type  Time(%)      Time     Calls       Avg       Min       Max  Name
#       API calls:   62.63%  389.09us         1  389.09us  389.09us  389.09us  cuDeviceTotalMem
#                    31.32%  194.55us        97  2.0050us     151ns  87.096us  cuDeviceGetAttribute
#                     4.85%  30.160us         1  30.160us  30.160us  30.160us  cuDeviceGetName
#                     0.61%  3.8190us         1  3.8190us  3.8190us  3.8190us  cuDeviceGetPCIBusId
#                     0.34%  2.1220us         3     707ns     188ns  1.4140us  cuDeviceGetCount
#                     0.19%  1.1750us         2     587ns     268ns     907ns  cuDeviceGet
#                     0.05%     329ns         1     329ns     329ns     329ns  cuDeviceGetUuid
# ======== Error: unified memory profiling failed.

# %%
# !which nsys
# Out:
# which: no nsys in (/cvmfs/sft.cern.ch/lcg/views/LCG_99cuda/x86_64-centos7-gcc8-opt/nvvm/bin:/cvmfs/sft.cern.ch/lcg/views/LCG_99cuda/x86_64-centos7-gcc8-opt/scripts:/cvmfs/sft.cern.ch/lcg/views/LCG_99cuda/x86_64-centos7-gcc8-opt/bin:/cvmfs/sft.cern.ch/lcg/releases/gcc/8.3.0-cebb0/x86_64-centos7/bin:/cvmfs/sft.cern.ch/lcg/releases/binutils/2.30-e5b21/x86_64-centos7/bin:/usr/local/texlive/2020/bin/x86_64-linux/:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/opt/nvidia-driver/bin)

# %%
# !ls /cvmfs/sft.cern.ch/lcg/views/LCG_99cuda/x86_64-centos7-gcc8-opt/bin
# Out:
# 2to3				   msgunfmt
# 2to3-3.7			   msguniq
# aclocal				   ms_print
# aclocal-1.16			   msql2mysql
# acyclic				   mvn
# addRandomAccess			   mvn.cmd
# aggregate_profile.pl		   mvnDebug
# agile-config			   mvnDebug.cmd
# agile-runmc			   mvnyjp
# aida2flat			   myisamchk
# aida2yoda			   myisam_ftdump
# ampt2u				   myisamlog
# anajob				   myisampack
# animate				   my_print_defaults
# ant				   myrocks_hotbackup
# ant.bat				   mysql
# ant.cmd				   mysqlaccess
# antenv.cmd			   mysqladmin
# antRun				   mysqlbinlog
# antRun.bat			   mysqlcheck
# antRun.pl			   mysql_client_test
# appletviewer			   mysql_config
# applygeo			   mysql_convert_table_format
# aria_chk			   mysqld
# aria_dump_log			   mysqld_multi
# aria_ftdump			   mysqld_safe
# aria_pack			   mysqld_safe_helper
# aria_read_log			   mysqldump
# array.sty			   mysqldumpslow
# assimp				   mysql_find_rows
# assistant			   mysql_fix_extensions
# autoconf			   mysqlhotcopy
# autoheader			   mysqlimport
# ...

# %%
# !ls /cvmfs/sft.cern.ch/lcg/views/LCG_99cuda/x86_64-centos7-gcc8-opt/
# Out:
# bin	etc	 jre	  macros   plugins    setup.sh	test
# cmake	fonts	 lib	  man	   python     share	tests
# config	icons	 lib64	  mkspecs  scripts    src	tutorials
# emacs	include  libexec  nvvm	   setup.csh  targets

# %%
# !/cvmfs/sft.cern.ch/lcg/releases/cuda/10.1-6ddea/x86_64-centos7-gcc8-opt/NsightSystems-2019.3/Target-x86_64/x86_64/nsys --version
# Out:
# NVIDIA Nsight Systems version 2019.3.3.3-a37c717

# %%
# Out:
# which: no nsys in (/cvmfs/sft.cern.ch/lcg/views/LCG_99cuda/x86_64-centos7-gcc8-opt/nvvm/bin:/cvmfs/sft.cern.ch/lcg/views/LCG_99cuda/x86_64-centos7-gcc8-opt/scripts:/cvmfs/sft.cern.ch/lcg/views/LCG_99cuda/x86_64-centos7-gcc8-opt/bin:/cvmfs/sft.cern.ch/lcg/releases/gcc/8.3.0-cebb0/x86_64-centos7/bin:/cvmfs/sft.cern.ch/lcg/releases/binutils/2.30-e5b21/x86_64-centos7/bin:/usr/local/texlive/2020/bin/x86_64-linux/:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/opt/nvidia-driver/bin)
